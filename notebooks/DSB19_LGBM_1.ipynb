# %%
import os
import gc


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scipy as sp

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold


from tqdm import tqdm

import lightgbm as lgb

# %%
path= '/mnt/7917b992-0701-4012-95c1-8b06e49e8f9b/2019DataScienceBowl/data/'

# %%
tqdm.pandas()
# Out:
# /home/axis/anaconda3/envs/ml/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
# Only load those columns in order to save space
keep_cols = ['event_id', 'game_session', 'installation_id', 'event_count', 'event_code', 'title', 'game_time', 'type', 'world']

# %%
# %%time
train = pd.read_csv(path+'train.csv', usecols=keep_cols)
# Out:
# CPU times: user 17.4 s, sys: 1.06 s, total: 18.4 s
# Wall time: 17.8 s

# %%
# %%time
test = pd.read_csv(path+'test.csv', usecols=keep_cols)
# Out:
# CPU times: user 2.07 s, sys: 67.8 ms, total: 2.14 s
# Wall time: 1.82 s

# %%
train_labels = pd.read_csv(path+'train_labels.csv')

# %%
submission = pd.read_csv(path+'sample_submission.csv')

# %%
# Copy the Assessment feature values
test_assess = test[test.type == 'Assessment'].copy()

# %%
# Copy the values from submission files as test labels
test_labels = submission.copy()

# %%
test_labels['title'] = test_labels.installation_id.progress_apply(
    lambda install_id: test_assess[test_assess.installation_id == install_id].iloc[-1].title
)
# Out:
# 100%|██████████| 1000/1000 [00:05<00:00, 189.25it/s]

# %%
def group_and_reduce(df, df_labels):
    """
    Author: https://www.kaggle.com/xhlulu/
    Source: https://www.kaggle.com/xhlulu/ds-bowl-2019-simple-lgbm-using-aggregated-data
    """
    
    # First only filter the useful part of the df
    df = df[df.installation_id.isin(df_labels.installation_id.unique())]
    
    # group1 is am intermediary "game session" group,
    # which are reduced to one record by game session. group1 takes
    # the max value of game_time (final game time in a session) and 
    # of event_count (total number of events happened in the session).
    group1 = df.drop(columns=['event_id', 'event_code']).groupby(
        ['game_session', 'installation_id', 'title', 'type', 'world']
    ).max().reset_index()

    # group3, group4, group5 are grouped by installation_id 
    # and reduced using summation and other summary stats
    group3 = (
        pd.get_dummies(
            group1.drop(columns=['game_session', 'event_count', 'game_time']),
            columns=['title', 'type', 'world'])
        .groupby(['installation_id'])
        .sum()
    )

    group4 = (
        group1[['installation_id', 'event_count', 'game_time']]
        .groupby(['installation_id'])
        .agg([np.sum, np.mean, np.std, np.min, np.max])
    )
    
    # Additional stats on group1
    world_time_stats = compute_game_time_stats(group1, 'world')
    type_time_stats = compute_game_time_stats(group1, 'type')
    
    return (
        group3.join(group4)
        .join(world_time_stats)
        .join(type_time_stats)
        .fillna(0)
    )

# %%
def compute_game_time_stats(group1, col):
    return group1[
        ['installation_id', col, 'event_count', 'game_time']
    ].groupby(['installation_id', col]).agg(
        [np.mean, np.sum, np.std]
    ).reset_index().pivot(
        columns=col,
        index='installation_id'
    )

# %%
# %%time
train_small = group_and_reduce(train, train_labels)
test_small = group_and_reduce(test, test_labels)

print(train_small.shape)
train_small.head()
# Out:
# /home/axis/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/reshape/merge.py:617: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# /home/axis/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/reshape/merge.py:617: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 3 on the right)
#   warnings.warn(msg, UserWarning)
# (3614, 110)
# CPU times: user 6.11 s, sys: 493 ms, total: 6.6 s
# Wall time: 4.37 s
#                  title_12 Monkeys  title_Air Show  title_All Star Sorting  \
# installation_id
# 0006a69f                      2.0             2.0                     4.0
# 0006c192                      1.0             0.0                     0.0
# 00129856                      0.0             0.0                     0.0
# 001d0ed0                      0.0             0.0                     0.0
# 00225f67                      1.0             1.0                     1.0
#
#                  title_Balancing Act  title_Bird Measurer (Assessment)  \
# installation_id
# 0006a69f                         0.0                               2.0
# 0006c192                         2.0                               1.0
# 00129856                         1.0                               1.0
# 001d0ed0                         2.0                               1.0
# 00225f67                         1.0                               1.0
#
#                  title_Bottle Filler (Activity)  title_Bubble Bath  \
# installation_id
# 0006a69f                                    2.0                2.0
# 0006c192                                    1.0                1.0
# 00129856                                    2.0                0.0
# 001d0ed0                                    0.0                0.0
# 00225f67                                    0.0                0.0
#
#                  title_Bug Measurer (Activity)  \
# installation_id
# 0006a69f                                   2.0
# 0006c192                                   1.0
# 00129856                                   2.0
# 001d0ed0                                   0.0
# 00225f67                                   1.0
#
#                  title_Cart Balancer (Assessment)  \
# installation_id
# 0006a69f                                      0.0
# 0006c192                                      0.0
# 00129856                                      0.0
# 001d0ed0                                      2.0
# 00225f67                                      0.0
#
#                  title_Cauldron Filler (Assessment)  ...  \
# installation_id                                      ...
# 0006a69f                                        0.0  ...
# 0006c192                                        2.0  ...
# 00129856                                        0.0  ...
# 001d0ed0                                        0.0  ...
# 00225f67                                        0.0  ...
#
#                  (game_time, mean, Clip)  (game_time, mean, Game)  \
# installation_id
# 0006a69f                             0.0            106966.450000
# 0006c192                             0.0             88345.500000
# 00129856                             0.0                 0.000000
# 001d0ed0                             0.0            158426.166667
# 00225f67                             0.0            129984.750000
#
#                  (game_time, sum, Activity)  (game_time, sum, Assessment)  \
# installation_id
# 0006a69f                          3199695.0                      236429.0
# 0006c192                          1210530.0                      323061.0
# 00129856                          1021179.0                       39742.0
# 001d0ed0                            92282.0                      201941.0
# 00225f67                           294517.0                       35637.0
#
#                  (game_time, sum, Clip)  (game_time, sum, Game)  \
# installation_id
# 0006a69f                            0.0               2139329.0
# 0006c192                            0.0                530073.0
# 00129856                            0.0                     0.0
# 001d0ed0                            0.0                950557.0
# 00225f67                            0.0                519939.0
#
#                  (game_time, std, Activity)  (game_time, std, Assessment)  \
# installation_id
# 0006a69f                      350054.566401                  28330.303185
# 0006c192                      127422.782500                  98940.202632
# 00129856                      130499.803239                  28043.854942
# 001d0ed0                       24694.997226                  17737.374861
# 00225f67                       49028.831364                  12301.536672
#
#                  (game_time, std, Clip)  (game_time, std, Game)
# installation_id
# 0006a69f                            0.0            58189.254197
# 0006c192                            0.0            62500.291205
# 00129856                            0.0                0.000000
# 001d0ed0                            0.0           123969.846618
# 00225f67                            0.0            65432.543128
#
# [5 rows x 110 columns]

# %%
titles = train_labels.title.unique()
title2mode = {}

for title in titles:
    mode = train_labels[train_labels.title == title].accuracy_group.value_counts().index[0]
    title2mode[title] = mode

train_labels['title_mode'] = train_labels.title.apply(lambda title: title2mode[title])
test_labels['title_mode'] = test_labels.title.apply(lambda title: title2mode[title])

# %%
final_train = pd.get_dummies(
    (
        train_labels.set_index('installation_id')
        .drop(columns=['num_correct', 'num_incorrect', 'accuracy', 'game_session'])
        .join(train_small)
    ), 
    columns=['title']
)

# Experimental: only take the last record of each installation
final_train = final_train.reset_index().groupby('installation_id').apply(lambda x: x.iloc[-1])
final_train = final_train.drop(columns='installation_id')

print(final_train.shape)
final_train.head()
# Out:
# (3614, 117)
#                  accuracy_group  title_mode  title_12 Monkeys  title_Air Show  \
# installation_id
# 0006a69f                      3           0               2.0             2.0
# 0006c192                      0           3               1.0             0.0
# 00129856                      3           0               0.0             0.0
# 001d0ed0                      3           3               0.0             0.0
# 00225f67                      0           0               1.0             1.0
#
#                  title_All Star Sorting  title_Balancing Act  \
# installation_id
# 0006a69f                            4.0                  0.0
# 0006c192                            0.0                  2.0
# 00129856                            0.0                  1.0
# 001d0ed0                            0.0                  2.0
# 00225f67                            1.0                  1.0
#
#                  title_Bird Measurer (Assessment)  \
# installation_id
# 0006a69f                                      2.0
# 0006c192                                      1.0
# 00129856                                      1.0
# 001d0ed0                                      1.0
# 00225f67                                      1.0
#
#                  title_Bottle Filler (Activity)  title_Bubble Bath  \
# installation_id
# 0006a69f                                    2.0                2.0
# 0006c192                                    1.0                1.0
# 00129856                                    2.0                0.0
# 001d0ed0                                    0.0                0.0
# 00225f67                                    0.0                0.0
#
#                  title_Bug Measurer (Activity)  ...  (game_time, sum, Game)  \
# installation_id                                 ...
# 0006a69f                                   2.0  ...               2139329.0
# 0006c192                                   1.0  ...                530073.0
# 00129856                                   2.0  ...                     0.0
# 001d0ed0                                   0.0  ...                950557.0
# 00225f67                                   1.0  ...                519939.0
#
#                  (game_time, std, Activity)  (game_time, std, Assessment)  \
# installation_id
# 0006a69f                      350054.566401                  28330.303185
# 0006c192                      127422.782500                  98940.202632
# 00129856                      130499.803239                  28043.854942
# 001d0ed0                       24694.997226                  17737.374861
# 00225f67                       49028.831364                  12301.536672
#
#                  (game_time, std, Clip)  (game_time, std, Game)  \
# installation_id
# 0006a69f                            0.0            58189.254197
# 0006c192                            0.0            62500.291205
# 00129856                            0.0                0.000000
# 001d0ed0                            0.0           123969.846618
# 00225f67                            0.0            65432.543128
#
#                  title_Bird Measurer (Assessment)  \
# installation_id
# 0006a69f                                        1
# 0006c192                                        0
# 00129856                                        1
# 001d0ed0                                        0
# 00225f67                                        1
#
#                  title_Cart Balancer (Assessment)  \
# installation_id
# 0006a69f                                        0
# 0006c192                                        0
# 00129856                                        0
# 001d0ed0                                        0
# 00225f67                                        0
#
#                  title_Cauldron Filler (Assessment)  \
# installation_id
# 0006a69f                                          0
# 0006c192                                          0
# 00129856                                          0
# 001d0ed0                                          0
# 00225f67                                          0
#
#                  title_Chest Sorter (Assessment)  \
# installation_id
# 0006a69f                                       0
# 0006c192                                       0
# 00129856                                       0
# 001d0ed0                                       0
# 00225f67                                       0
#
#                  title_Mushroom Sorter (Assessment)
# installation_id
# 0006a69f                                          0
# 0006c192                                          1
# 00129856                                          0
# 001d0ed0                                          1
# 00225f67                                          0
#
# [5 rows x 117 columns]

# %%
final_test = pd.get_dummies(test_labels.set_index('installation_id').join(test_small), columns=['title'])

print(final_test.shape)
final_test.head()
# Out:
# (1000, 117)
#                  accuracy_group  title_mode  title_12 Monkeys  title_Air Show  \
# installation_id
# 00abaee7                      3           3               2.0             0.0
# 01242218                      3           3               1.0             1.0
# 017c5718                      3           3               0.0             0.0
# 01a44906                      3           3               1.0             0.0
# 01bc6cb6                      3           3               0.0             0.0
#
#                  title_All Star Sorting  title_Balancing Act  \
# installation_id
# 00abaee7                            1.0                  1.0
# 01242218                            1.0                  3.0
# 017c5718                            0.0                  0.0
# 01a44906                            1.0                  0.0
# 01bc6cb6                            3.0                  1.0
#
#                  title_Bird Measurer (Assessment)  \
# installation_id
# 00abaee7                                      0.0
# 01242218                                      1.0
# 017c5718                                      0.0
# 01a44906                                      0.0
# 01bc6cb6                                      0.0
#
#                  title_Bottle Filler (Activity)  title_Bubble Bath  \
# installation_id
# 00abaee7                                    0.0                0.0
# 01242218                                    2.0                1.0
# 017c5718                                    0.0                0.0
# 01a44906                                    0.0                0.0
# 01bc6cb6                                    0.0                0.0
#
#                  title_Bug Measurer (Activity)  ...  (game_time, sum, Game)  \
# installation_id                                 ...
# 00abaee7                                   2.0  ...               2285229.0
# 01242218                                   1.0  ...               1420909.0
# 017c5718                                   0.0  ...                     0.0
# 01a44906                                   0.0  ...                 77204.0
# 01bc6cb6                                   0.0  ...                984880.0
#
#                  (game_time, std, Activity)  (game_time, std, Assessment)  \
# installation_id
# 00abaee7                       36886.664956                  21240.073493
# 01242218                       98521.245018                  32761.743006
# 017c5718                        6389.416875                      0.000000
# 01a44906                       43064.217188                      0.000000
# 01bc6cb6                           0.000000                      0.000000
#
#                  (game_time, std, Clip)  (game_time, std, Game)  \
# installation_id
# 00abaee7                            0.0            1.038605e+06
# 01242218                            0.0            3.779781e+04
# 017c5718                            0.0            0.000000e+00
# 01a44906                            0.0            0.000000e+00
# 01bc6cb6                            0.0            1.780426e+05
#
#                  title_Bird Measurer (Assessment)  \
# installation_id
# 00abaee7                                        0
# 01242218                                        0
# 017c5718                                        0
# 01a44906                                        0
# 01bc6cb6                                        0
#
#                  title_Cart Balancer (Assessment)  \
# installation_id
# 00abaee7                                        0
# 01242218                                        1
# 017c5718                                        0
# 01a44906                                        0
# 01bc6cb6                                        1
#
#                  title_Cauldron Filler (Assessment)  \
# installation_id
# 00abaee7                                          1
# 01242218                                          0
# 017c5718                                          0
# 01a44906                                          0
# 01bc6cb6                                          0
#
#                  title_Chest Sorter (Assessment)  \
# installation_id
# 00abaee7                                       0
# 01242218                                       0
# 017c5718                                       0
# 01a44906                                       0
# 01bc6cb6                                       0
#
#                  title_Mushroom Sorter (Assessment)
# installation_id
# 00abaee7                                          0
# 01242218                                          0
# 017c5718                                          1
# 01a44906                                          1
# 01bc6cb6                                          0
#
# [5 rows x 117 columns]

# %%
def cv_train(X, y, cv, **kwargs):
    """
    Author: https://www.kaggle.com/xhlulu/
    Source: https://www.kaggle.com/xhlulu/ds-bowl-2019-simple-lgbm-using-aggregated-data
    """
    models = []
    
    kf = KFold(n_splits=cv, random_state=2019)
    
    for train, test in kf.split(X):
        x_train, x_val, y_train, y_val = X[train], X[test], y[train], y[test]
        
        train_set = lgb.Dataset(x_train, y_train)
        val_set = lgb.Dataset(x_val, y_val)
        
        model = lgb.train(train_set=train_set, valid_sets=[train_set, val_set], **kwargs)
        models.append(model)
        
        if kwargs.get("verbose_eval"):
            print("\n" + "="*50 + "\n")
    
    return models

def cv_predict(models, X):
    """
    Author: https://www.kaggle.com/xhlulu/
    Source: https://www.kaggle.com/xhlulu/ds-bowl-2019-simple-lgbm-using-aggregated-data
    """
    return np.mean([model.predict(X) for model in models], axis=0)

# %%
from sklearn.model_selection import KFold
small_labels = train_labels[['installation_id', 'accuracy_group']].set_index('installation_id')
train_joined = train_small.join(small_labels).dropna()
kf = KFold(n_splits=10, random_state=2019)
X = train_joined.drop(columns='accuracy_group').values
y = train_joined['accuracy_group'].values.astype(np.int32)
y_pred = np.zeros((len(test_small), 4))
for train, test in kf.split(X):
    x_train, x_val, y_train, y_val = X[train], X[test], y[train], y[test]
    train_set = lgb.Dataset(x_train, y_train)
    val_set = lgb.Dataset(x_val, y_val)

    params = {
        'learning_rate': 0.01,
        'bagging_fraction': 0.9,
        'feature_fraction': 0.9,
        'num_leaves': 14,
        'lambda_l1': 0.1,
        'lambda_l2': 1,
        'metric': 'multiclass',
        'objective': 'multiclass',
        'num_classes': 4,
        'random_state': 2019
    }

    model = lgb.train(params, train_set, num_boost_round=10000, early_stopping_rounds=300, valid_sets=[train_set, val_set], verbose_eval=100)
    y_pred += model.predict(test_small)
# Out:
# Training until validation scores don't improve for 300 rounds.
# [100]	training's multi_logloss: 1.14811	valid_1's multi_logloss: 1.16313
# [200]	training's multi_logloss: 1.11441	valid_1's multi_logloss: 1.1394
# [300]	training's multi_logloss: 1.09276	valid_1's multi_logloss: 1.12691
# [400]	training's multi_logloss: 1.07648	valid_1's multi_logloss: 1.12319
# [500]	training's multi_logloss: 1.06319	valid_1's multi_logloss: 1.12021
# [600]	training's multi_logloss: 1.05175	valid_1's multi_logloss: 1.1189
# [700]	training's multi_logloss: 1.04148	valid_1's multi_logloss: 1.11813
# [800]	training's multi_logloss: 1.03229	valid_1's multi_logloss: 1.1181
# [900]	training's multi_logloss: 1.02383	valid_1's multi_logloss: 1.11797
# [1000]	training's multi_logloss: 1.01594	valid_1's multi_logloss: 1.11735
# [1100]	training's multi_logloss: 1.00847	valid_1's multi_logloss: 1.11697
# [1200]	training's multi_logloss: 1.00148	valid_1's multi_logloss: 1.11716
# [1300]	training's multi_logloss: 0.994828	valid_1's multi_logloss: 1.11732
# [1400]	training's multi_logloss: 0.988627	valid_1's multi_logloss: 1.11783
# Early stopping, best iteration is:
# [1139]	training's multi_logloss: 1.00569	valid_1's multi_logloss: 1.11687
# Training until validation scores don't improve for 300 rounds.
# [100]	training's multi_logloss: 1.14569	valid_1's multi_logloss: 1.19008
# [200]	training's multi_logloss: 1.11149	valid_1's multi_logloss: 1.17658
# [300]	training's multi_logloss: 1.08914	valid_1's multi_logloss: 1.16931
# [400]	training's multi_logloss: 1.07287	valid_1's multi_logloss: 1.16579
# [500]	training's multi_logloss: 1.05987	valid_1's multi_logloss: 1.16406
# [600]	training's multi_logloss: 1.04847	valid_1's multi_logloss: 1.16324
# [700]	training's multi_logloss: 1.0383	valid_1's multi_logloss: 1.16242
# [800]	training's multi_logloss: 1.02908	valid_1's multi_logloss: 1.16243
# [900]	training's multi_logloss: 1.02063	valid_1's multi_logloss: 1.16173
# [1000]	training's multi_logloss: 1.01281	valid_1's multi_logloss: 1.16151
# [1100]	training's multi_logloss: 1.00547	valid_1's multi_logloss: 1.16159
# [1200]	training's multi_logloss: 0.998506	valid_1's multi_logloss: 1.16145
# [1300]	training's multi_logloss: 0.991999	valid_1's multi_logloss: 1.16152
# [1400]	training's multi_logloss: 0.985869	valid_1's multi_logloss: 1.16195
# [1500]	training's multi_logloss: 0.980074	valid_1's multi_logloss: 1.1624
# Early stopping, best iteration is:
# [1206]	training's multi_logloss: 0.998105	valid_1's multi_logloss: 1.16132
# Training until validation scores don't improve for 300 rounds.
# [100]	training's multi_logloss: 1.14641	valid_1's multi_logloss: 1.18128
# [200]	training's multi_logloss: 1.11262	valid_1's multi_logloss: 1.16711
# [300]	training's multi_logloss: 1.09072	valid_1's multi_logloss: 1.16073
# [400]	training's multi_logloss: 1.07429	valid_1's multi_logloss: 1.15703
# [500]	training's multi_logloss: 1.06066	valid_1's multi_logloss: 1.15439
# [600]	training's multi_logloss: 1.04931	valid_1's multi_logloss: 1.15342
# [700]	training's multi_logloss: 1.03932	valid_1's multi_logloss: 1.1524
# [800]	training's multi_logloss: 1.03021	valid_1's multi_logloss: 1.15222
# [900]	training's multi_logloss: 1.02195	valid_1's multi_logloss: 1.15212
# [1000]	training's multi_logloss: 1.01418	valid_1's multi_logloss: 1.15174
# [1100]	training's multi_logloss: 1.00694	valid_1's multi_logloss: 1.15147
# [1200]	training's multi_logloss: 1.00033	valid_1's multi_logloss: 1.1513
# [1300]	training's multi_logloss: 0.993958	valid_1's multi_logloss: 1.1511
# [1400]	training's multi_logloss: 0.988101	valid_1's multi_logloss: 1.1513
# [1500]	training's multi_logloss: 0.982505	valid_1's multi_logloss: 1.15148
# [1600]	training's multi_logloss: 0.977033	valid_1's multi_logloss: 1.15167
# Early stopping, best iteration is:
# [1325]	training's multi_logloss: 0.992458	valid_1's multi_logloss: 1.15096
# Training until validation scores don't improve for 300 rounds.
# [100]	training's multi_logloss: 1.14464	valid_1's multi_logloss: 1.19675
# [200]	training's multi_logloss: 1.11091	valid_1's multi_logloss: 1.186
# [300]	training's multi_logloss: 1.0882	valid_1's multi_logloss: 1.1799
# [400]	training's multi_logloss: 1.07168	valid_1's multi_logloss: 1.1764
# [500]	training's multi_logloss: 1.05854	valid_1's multi_logloss: 1.17462
# [600]	training's multi_logloss: 1.04733	valid_1's multi_logloss: 1.17359
# [700]	training's multi_logloss: 1.03717	valid_1's multi_logloss: 1.17319
# [800]	training's multi_logloss: 1.02792	valid_1's multi_logloss: 1.17334
# [900]	training's multi_logloss: 1.01937	valid_1's multi_logloss: 1.17357
# [1000]	training's multi_logloss: 1.01164	valid_1's multi_logloss: 1.1731
# Early stopping, best iteration is:
# [763]	training's multi_logloss: 1.03125	valid_1's multi_logloss: 1.17301
# Training until validation scores don't improve for 300 rounds.
# [100]	training's multi_logloss: 1.14392	valid_1's multi_logloss: 1.19258
# [200]	training's multi_logloss: 1.10972	valid_1's multi_logloss: 1.17644
# [300]	training's multi_logloss: 1.08732	valid_1's multi_logloss: 1.16828
# [400]	training's multi_logloss: 1.0706	valid_1's multi_logloss: 1.16339
# [500]	training's multi_logloss: 1.05718	valid_1's multi_logloss: 1.15974
# [600]	training's multi_logloss: 1.04582	valid_1's multi_logloss: 1.15782
# [700]	training's multi_logloss: 1.03582	valid_1's multi_logloss: 1.15653
# [800]	training's multi_logloss: 1.02652	valid_1's multi_logloss: 1.15611
# [900]	training's multi_logloss: 1.01796	valid_1's multi_logloss: 1.15536
# [1000]	training's multi_logloss: 1.01003	valid_1's multi_logloss: 1.15486
# [1100]	training's multi_logloss: 1.00274	valid_1's multi_logloss: 1.15473
# [1200]	training's multi_logloss: 0.995819	valid_1's multi_logloss: 1.15419
# [1300]	training's multi_logloss: 0.989364	valid_1's multi_logloss: 1.15402
# [1400]	training's multi_logloss: 0.983349	valid_1's multi_logloss: 1.15367
# [1500]	training's multi_logloss: 0.977714	valid_1's multi_logloss: 1.15382
# [1600]	training's multi_logloss: 0.972393	valid_1's multi_logloss: 1.15395
# Early stopping, best iteration is:
# [1363]	training's multi_logloss: 0.985499	valid_1's multi_logloss: 1.15364
# Training until validation scores don't improve for 300 rounds.
# [100]	training's multi_logloss: 1.14618	valid_1's multi_logloss: 1.18262
# [200]	training's multi_logloss: 1.11152	valid_1's multi_logloss: 1.16645
# [300]	training's multi_logloss: 1.08943	valid_1's multi_logloss: 1.15826
# [400]	training's multi_logloss: 1.07289	valid_1's multi_logloss: 1.15374
# [500]	training's multi_logloss: 1.0597	valid_1's multi_logloss: 1.15158
# [600]	training's multi_logloss: 1.04827	valid_1's multi_logloss: 1.15041
# [700]	training's multi_logloss: 1.03789	valid_1's multi_logloss: 1.14939
# [800]	training's multi_logloss: 1.02859	valid_1's multi_logloss: 1.14917
# [900]	training's multi_logloss: 1.02017	valid_1's multi_logloss: 1.14906
# [1000]	training's multi_logloss: 1.01254	valid_1's multi_logloss: 1.14884
# [1100]	training's multi_logloss: 1.00525	valid_1's multi_logloss: 1.14892
# [1200]	training's multi_logloss: 0.998469	valid_1's multi_logloss: 1.14926
# Early stopping, best iteration is:
# [959]	training's multi_logloss: 1.0156	valid_1's multi_logloss: 1.14874
# Training until validation scores don't improve for 300 rounds.
# [100]	training's multi_logloss: 1.14795	valid_1's multi_logloss: 1.16137
# [200]	training's multi_logloss: 1.11337	valid_1's multi_logloss: 1.14936
# [300]	training's multi_logloss: 1.09103	valid_1's multi_logloss: 1.1432
# [400]	training's multi_logloss: 1.07447	valid_1's multi_logloss: 1.14088
# [500]	training's multi_logloss: 1.06087	valid_1's multi_logloss: 1.14084
# [600]	training's multi_logloss: 1.0493	valid_1's multi_logloss: 1.14111
# [700]	training's multi_logloss: 1.03909	valid_1's multi_logloss: 1.14173
# Early stopping, best iteration is:
# [430]	training's multi_logloss: 1.07011	valid_1's multi_logloss: 1.14053
# Training until validation scores don't improve for 300 rounds.
# [100]	training's multi_logloss: 1.14884	valid_1's multi_logloss: 1.15201
# [200]	training's multi_logloss: 1.11447	valid_1's multi_logloss: 1.135
# [300]	training's multi_logloss: 1.092	valid_1's multi_logloss: 1.12697
# [400]	training's multi_logloss: 1.0753	valid_1's multi_logloss: 1.12452
# [500]	training's multi_logloss: 1.06157	valid_1's multi_logloss: 1.12427
# [600]	training's multi_logloss: 1.05014	valid_1's multi_logloss: 1.12406
# [700]	training's multi_logloss: 1.03986	valid_1's multi_logloss: 1.12375
# [800]	training's multi_logloss: 1.0308	valid_1's multi_logloss: 1.12424
# [900]	training's multi_logloss: 1.02253	valid_1's multi_logloss: 1.12449
# [1000]	training's multi_logloss: 1.01487	valid_1's multi_logloss: 1.12422
# Early stopping, best iteration is:
# [713]	training's multi_logloss: 1.03861	valid_1's multi_logloss: 1.12368
# Training until validation scores don't improve for 300 rounds.
# [100]	training's multi_logloss: 1.1474	valid_1's multi_logloss: 1.17931
# [200]	training's multi_logloss: 1.11474	valid_1's multi_logloss: 1.15584
# [300]	training's multi_logloss: 1.09287	valid_1's multi_logloss: 1.14527
# [400]	training's multi_logloss: 1.0764	valid_1's multi_logloss: 1.13964
# [500]	training's multi_logloss: 1.06297	valid_1's multi_logloss: 1.13578
# [600]	training's multi_logloss: 1.05162	valid_1's multi_logloss: 1.13374
# [700]	training's multi_logloss: 1.04146	valid_1's multi_logloss: 1.13254
# [800]	training's multi_logloss: 1.03219	valid_1's multi_logloss: 1.13177
# [900]	training's multi_logloss: 1.02356	valid_1's multi_logloss: 1.1314
# [1000]	training's multi_logloss: 1.01557	valid_1's multi_logloss: 1.13114
# [1100]	training's multi_logloss: 1.0082	valid_1's multi_logloss: 1.13094
# [1200]	training's multi_logloss: 1.00139	valid_1's multi_logloss: 1.13092
# [1300]	training's multi_logloss: 0.995009	valid_1's multi_logloss: 1.13069
# [1400]	training's multi_logloss: 0.988945	valid_1's multi_logloss: 1.13118
# [1500]	training's multi_logloss: 0.983208	valid_1's multi_logloss: 1.1315
# [1600]	training's multi_logloss: 0.977755	valid_1's multi_logloss: 1.1319
# Early stopping, best iteration is:
# [1304]	training's multi_logloss: 0.994771	valid_1's multi_logloss: 1.13067
# Training until validation scores don't improve for 300 rounds.
# [100]	training's multi_logloss: 1.15152	valid_1's multi_logloss: 1.13742
# [200]	training's multi_logloss: 1.11772	valid_1's multi_logloss: 1.12013
# [300]	training's multi_logloss: 1.09563	valid_1's multi_logloss: 1.11139
# [400]	training's multi_logloss: 1.07906	valid_1's multi_logloss: 1.10966
# [500]	training's multi_logloss: 1.06566	valid_1's multi_logloss: 1.11188
# [600]	training's multi_logloss: 1.05435	valid_1's multi_logloss: 1.11311
# [700]	training's multi_logloss: 1.04423	valid_1's multi_logloss: 1.11311
# Early stopping, best iteration is:
# [410]	training's multi_logloss: 1.07759	valid_1's multi_logloss: 1.10943

# %%
X_test = final_test.drop(columns=['accuracy_group'])
test_pred = cv_predict(models=models, X=X_test).argmax(axis=1)

final_test['accuracy_group'] = test_pred
final_test[['accuracy_group']].to_csv('submission.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-0489126893ed> in <module>
#       1 X_test = final_test.drop(columns=['accuracy_group'])
# ----> 2 test_pred = cv_predict(models=models, X=X_test).argmax(axis=1)
#       3
#       4 final_test['accuracy_group'] = test_pred
#       5 final_test[['accuracy_group']].to_csv('submission.csv')
#
# NameError: name 'models' is not defined
